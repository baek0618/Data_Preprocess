# %%
#제목 전처리 test

import re
 
ex = '꿈과 광기의 왕국 The.Kingdom.of.Dreams.and.Madness.2013.JAPANESE.1080p.BluRay.H264.AAC-VXT'
m = re.sub('[^a-z|A-Z|0-9]','' ,ex )
z = re.search('20..|19..',m)
print(m[:z.regs[0][0]])
# Out:
# TheKingdomofDreamsandMadness

# %%
# -*- coding: utf-8 -*-
import glob
import os
import re

def clear_dir(path):
    print('[+] 현재 경로       : ' + path)
    file_list = glob.glob(path+'/*')
    for item in file_list:
        if item.endswith('.txt'):
            os.remove(item)
            
def make_file(f_in,input_file_name,path_len):
    output_file_name = re.sub('[^a-z|A-Z|0-9]','' ,input_file_name ) # 컴파일과 매치를 한번에 했다. 
    idx = re.search('20..|19..',output_file_name)
    output_file_name = input_file_name[:path_len+input_file_name.count('\\')+1]+output_file_name[path_len:idx.regs[0][0]]+'.txt'

    if input_file_name.endswith('.srt'):
        f_out = open(output_file_name, 'w',encoding='utf8')
    else :
        f_out = open(output_file_name, 'w')

    lines = filter(None, (line.rstrip() for line in f_in))

    for line in lines:
        
        line = re.sub('<br>|-','',line) # 추가
        if input_file_name.endswith('.smi'):
            # <SAMI>, <HEAD>, <TITLE>, <BODY>, <SYNC Start=1124> 
            if line.startswith('<') or line.startswith('{') or line.startswith('#'):
                continue
            #    color:white;
            if line.endswith(';') or line.endswith('}') or line.endswith('-->'):
                continue
            #</SAMI>, </BODY>
            if line.endswith('BODY>') or line.endswith('SAMI>'):
                continue
            if line.endswith('<br>'):
                line = line[:-4]
                line = line + ' '
                f_out.write(line)
                continue
        if input_file_name.endswith('.srt'):
            if line.isdigit() and len(line) < 4:
                continue
            if line.startswith('0'):
                continue
            if line.startswith('<font'):
                continue
        f_out.write(line + '\r\n')
    f_out.close()
            
def encoding_func(input_file_name, path_len):
    error=''
    print(input_file_name)    
    try:
        with open(input_file_name) as f_in:
            make_file(f_in,input_file_name,path_len)
    except:
        try:
            with open(input_file_name,encoding='utf8') as f_in:
                make_file(f_in,input_file_name,path_len)
        except:
            print('\n[error]',input_file_name,'\n')
            error = input_file_name
    f_in.close()
    return error


def main():
    print('@')
    error_lst=[]
    p = 'E:\\data\\movie110'   ### 경로 설정해줄 것.
    for(path, dir, files) in os.walk(p):
        clear_dir(path)
        subtitle_list = glob.glob(path+'\\*.smi')
        subtitle_list.extend(glob.glob(path+'\\*.srt'))
        for file_name in subtitle_list:
            error_t=encoding_func(file_name,len(p)-p.count('\\')-1)
            if (error_t!=''):
                error_lst.append(error_t)
    print('[+] 전체 디렉터리 자막 추출 성공',end='\n\n')
    print('[error_list]\n',error_lst,'\n')
    for item in error_lst:
        output_file_name = re.sub('[^a-z|A-Z|0-9]','' ,item ) # 컴파일과 매치를 한번에 했다. 
        idx = re.search('20..|19..',output_file_name)
        output_file_name = item[:len(p)-p.count('\\')-1+item.count('\\')+1]+output_file_name[len(p)-p.count('\\')-1:idx.regs[0][0]]+'.txt'
        print('[삭제]',output_file_name)
        os.remove(output_file_name)
    
if __name__ == '__main__':
    main()
# Out:
# @
# [+] 현재 경로       : E:\data\movie110
# E:\data\movie110\13.Eerie.2013.1080p.BluRay.x264-CREEPSHOW.smi
# E:\data\movie110\A.Christmas.Prince.The.Royal.Wedding.2018.1080p.NF.WEB-DL.DDP5.1.H264-CMRG.smi
# E:\data\movie110\alpha.2018.1080p.bluray.x264-drones.smi
# E:\data\movie110\Angelas.Christmas.2018.1080p.NF.WEB-DL.DUAL.DDP5.1.x264-iFT.smi
# E:\data\movie110\Behind.the.Fallout.1080p.BluRay.x264.DD2.0-FGT.smi
# E:\data\movie110\Black+Swan+2010+1080p+Bluray+x265+HEVC+10bit+AAC+5.1+Tigole_KOR.smi
# E:\data\movie110\Burn+After+Reading+2008+1080p+x265+AAC51+Tigole_KOR.smi
# E:\data\movie110\Burning.Bright.2010.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\BuyBust.2018.BluRay.1080p.DTS.x265.10bit-CHD.smi
# E:\data\movie110\Cam.2018.1080p.NF.WEB-DL.DD5.1.H264-CMRG.smi
# E:\data\movie110\Carriers.2009.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\Chatroom.2010.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\Columbus.2017.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\Crazy.Rich.Asians.2018.1080p.BluRay.x264.DTS-Zoom.smi
# E:\data\movie110\Detachment.2011.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\Dhoom+2+2006+Hindi+1080p+Blu-Ray+x264+DD+5.1+MSubs-HDSector-[Original].smi
# E:\data\movie110\Elle.2016.1080p.BluRay.x264-[YTS.AM].smi
# E:\data\movie110\Halloween.Resurrection.2002.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\Hotel.Salvation.2016.1080p.BluRay.x264-[YTS.AM]-[Original].smi
# E:\data\movie110\How.to.Get.Over.a.Breakup.2018.1080p.NF.WEB-DL.DDP5.1.H264-CMRG.smi
# E:\data\movie110\Infection+2004+.smi
# E:\data\movie110\Iron.Men.2017.720p.BluRay.x264-[YTS.AM].smi
# E:\data\movie110\Little.Ashes.2008.1080p.BluRay.H264.AAC-RARBG-[Original].smi
# E:\data\movie110\May.The.Devil.Take.You.2018.INDONESIAN.1080p.NF.WEBRip.DD5.1.x264-TOMMY.smi
# E:\data\movie110\Mile.22.2018.1080p.BluRay.X264-AMIABLE.smi
# E:\data\movie110\Nothing.To.Hide.2018.1080p.NF.WEB-DL.DD5.1.H264-CMRG.smi
# E:\data\movie110\Papillon.2017.1080p.BluRay.x264.DTS-HD.MA.5.1-FGT.smi
# E:\data\movie110\Peppermint.2018.1080p.BluRay.x264-SPARKS.smi
# E:\data\movie110\Planet.Hulk.2010.1080p.BluRay.H264.AAC-RARBG-[Original].smi
# E:\data\movie110\Puzzle.2018.1080p.WEB-DL.DD5.1.H264-FGT.smi
# E:\data\movie110\Rangreza+2017+-+720p+-+WEBRip+-+x264+-+AC3+5.1+-+ESubs+-+Madhu.smi
# E:\data\movie110\Renegades.2017.1080p.BluRay.x264-[YTS.AM].smi
#
# [error] E:\data\movie110\Renegades.2017.1080p.BluRay.x264-[YTS.AM].smi
#
# E:\data\movie110\Rogue.2007.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\Serious.Moonlight.2009.1080p.BluRay.H264.AAC-RARBG-[Original].smi
# E:\data\movie110\Storm.Letters.van.Vuur.2017.1080p.BluRay.DD2.0.x264.CZ-BST.smi
# E:\data\movie110\Superhero.Movie.2008.720p.BluRay.x264-[YTS.AM].smi
# E:\data\movie110\The.Ballad.of.Buster.Scruggs.2018.1080p.NF.WEB-DL.DD5.1.H264-CMRG.smi
# E:\data\movie110\The.Beautiful.Country.2004.1080p.AMZN.WEB-DL.DDP5.1.x264-ABM.smi
# E:\data\movie110\The.Breed.2006.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\The.Meg.2018.1080p.BluRay.x264.DTS-Zoom[Original].smi
# E:\data\movie110\The.Princess.Switch.2018.1080p.NF.WEB-DL.DD5.1.H264-CMRG.smi
# E:\data\movie110\The.Program.2015.1080p.BluRay.H264.AAC-RARBG-[Original].smi
# E:\data\movie110\The.Vanishing.Of.Sidney.Hall.2017.1080p.BluRay.H264.AAC-RARBG-[Original].smi
# E:\data\movie110\The.Woods.2015.1080p.BluRay.H264.AAC-RARBG.smi
# E:\data\movie110\The.World.Is.Yours.2018.1080p.NF.WEB-DL.KOR.smi
# E:\data\movie110\To.the.Fore.2015.720p.BluRay.x264-WiKi-[Original].smi
# E:\data\movie110\un.homme.a.la.hauteur.2016.french.1080p.bluray.x264-lost.smi
# E:\data\movie110\Un.Plus.Une.2015.FRENCH.1080p.BluRay.x264-LOST.smi
# E:\data\movie110\When.I.Get.Home.My.Wife.Always.Pretends.to.Be.Dead.2018.BluRay.x264-WiKi.smi
#
# [error] E:\data\movie110\When.I.Get.Home.My.Wife.Always.Pretends.to.Be.Dead.2018.BluRay.x264-WiKi.smi
#
# E:\data\movie110\you.were.never.really.here.2017.limited.1080p.bluray.x264-usury.smi
# E:\data\movie110\꿈과 광기의 왕국 The.Kingdom.of.Dreams.and.Madness.2013.JAPANESE.1080p.BluRay.H264.AAC-VXT.smi
# E:\data\movie110\리틀 마에스트로The.Little.Maestro 2013.HDTV.720p.AAC.x264-YYeTs.smi
#
# [error] E:\data\movie110\리틀 마에스트로The.Little.Maestro 2013.HDTV.720p.AAC.x264-YYeTs.smi
#
# E:\data\movie110\베놈 Venom.aka.Blackwater.2005.1080p.BluRay.X264-OEM1080.smi
# E:\data\movie110\블러드 Blood.The.Last.Vampire.2009.1080p.BluRay.x264.DTS-FGT.smi
# E:\data\movie110\쇼크웨이브 Shock.Wave.2017.1080p.BluRay.x264-SPRiNTER.smi
# E:\data\movie110\American.Chaos.2018.1080p.AMZN.WEB-DL.DDP5.1.H.264-NTG.srt
# E:\data\movie110\Flower+and+Snake+2004+UNCUT+1080p+Blu-ray+AVC+TrueHD+2.0+DIY-TTG.srt
# E:\data\movie110\The.Clovehitch.Killer.2018.1080p.WEB-DL.DD5.1.H264-FGT.srt
# E:\data\movie110\The.Marine.6.Close.Quarters.2018.720p.BluRay.H264.AAC-RARBG.srt
# [+] 전체 디렉터리 자막 추출 성공
#
# [error_list]
#  ['E:\\data\\movie110\\Renegades.2017.1080p.BluRay.x264-[YTS.AM].smi', 'E:\\data\\movie110\\When.I.Get.Home.My.Wife.Always.Pretends.to.Be.Dead.2018.BluRay.x264-WiKi.smi', 'E:\\data\\movie110\\리틀 마에스트로The.Little.Maestro 2013.HDTV.720p.AAC.x264-YYeTs.smi']
#
# [삭제] E:\data\movie110\Renegades.txt
# [삭제] E:\data\movie110\WhenIGetHomeMyWifeAlwaysPretendstoBeDead.txt
# [삭제] E:\data\movie110\TheLittleMaestro.txt
